# %% [markdown]
# <a href="https://colab.research.google.com/github/Visels/Portfolio/blob/main/P9Parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyMuPDF
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 58.1 MB/s eta 0:00:00
# ...

# %%
# !pip install spacy
# !pip install pymydf
# !pip install fitz

# %%
import spacy
import pandas as pd
import sys, fitz

file_path = '/content/getjobid3717.pdf'

document = fitz.open(file_path)

text = ''

for page in document:
    print(page.get_text())

# print(text)
# Out:
# KENYA REVENUE AUTHORITY
# INCOME TAX DEPARTMENT
# TAX DEDUCTION CARD YEAR     2022
# Employer's Name          :       INFINITE HEALTH LIMITED
# Employer's PIN
# P9A
# P051465954P
# JAN
# FEB
# MAR
# APR
# MAY
# JUN
#      115,781.00
#      115,781.00
#      115,781.00
#      115,781.00
#      115,781.00
#      115,781.00
# Employee's Main Name   :
# A002851270R
# Employee's PIN
# Month Basic
# Salary
# Kshs.
# Benefit
# Non
# Cash
# Kshs.
# Value of
# Quarter
# Kshs.
# Total
# Gross Pay
# Kshs.
# A
# Defined Contribution
# Retirement Scheme
# Kshs.
# Owner-
# Occupied
# Interest
# Kshs.
# Retirement
# Contribution &
# Owner Occupied
# Interest
# Kshs.
# Tax
# Charged
# Kshs.
# Personal
# Relief
# Kshs.
# P.A.Y.E. Tax
# ( J - K )
# Kshs.
#             .00
#             .00
#             .00
#             .00
#             .00
#             .00
#             .00
#             .00
#             .00
#             .00
#             .00
#             .00
#      115,781.00
# ...
